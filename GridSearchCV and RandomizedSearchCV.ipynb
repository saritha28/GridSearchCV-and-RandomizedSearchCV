# %%
# importing the dependencies
import numpy as np
import pandas as pd
import sklearn.datasets
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV

# %% [markdown]
# We will be working on the breast cancer dataset

# %%
# loading the data from sklearn
df = sklearn.datasets.load_breast_cancer

# %%
print(df)
# Out:
# <function load_breast_cancer at 0x000002197DF77C10>

# %%
# loading the data to a data frame
data_frame = pd.DataFrame(breast_cancer_dataset().data, columns = breast_cancer_dataset().feature_names)

# %%
# print the first 5 rows of the dataframe
data_frame.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst radius  worst texture  worst perimeter  \
# 0                 0.07871  ...         25.38          17.33           184.60
# 1                 0.05667  ...         24.99          23.41           158.80
# 2                 0.05999  ...         23.57          25.53           152.50
# 3                 0.09744  ...         14.91          26.50            98.87
# 4                 0.05883  ...         22.54          16.67           152.20
#
#    worst area  worst smoothness  worst compactness  worst concavity  \
# 0      2019.0            0.1622             0.6656           0.7119
# 1      1956.0            0.1238             0.1866           0.2416
# 2      1709.0            0.1444             0.4245           0.4504
# 3       567.7            0.2098             0.8663           0.6869
# 4      1575.0            0.1374             0.2050           0.4000
#
#    worst concave points  worst symmetry  worst fractal dimension
# 0                0.2654          0.4601                  0.11890
# 1                0.1860          0.2750                  0.08902
# 2                0.2430          0.3613                  0.08758
# 3                0.2575          0.6638                  0.17300
# 4                0.1625          0.2364                  0.07678
#
# [5 rows x 30 columns]

# %%
# adding the 'target' column to the data frame
data_frame['label'] = breast_cancer_dataset().target

# %%
# print the first 5 rows of the dataframe
data_frame.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst texture  worst perimeter  worst area  \
# 0                 0.07871  ...          17.33           184.60      2019.0
# 1                 0.05667  ...          23.41           158.80      1956.0
# 2                 0.05999  ...          25.53           152.50      1709.0
# 3                 0.09744  ...          26.50            98.87       567.7
# 4                 0.05883  ...          16.67           152.20      1575.0
#
#    worst smoothness  worst compactness  worst concavity  worst concave points  \
# 0            0.1622             0.6656           0.7119                0.2654
# 1            0.1238             0.1866           0.2416                0.1860
# 2            0.1444             0.4245           0.4504                0.2430
# 3            0.2098             0.8663           0.6869                0.2575
# 4            0.1374             0.2050           0.4000                0.1625
#
#    worst symmetry  worst fractal dimension  label
# 0          0.4601                  0.11890      0
# 1          0.2750                  0.08902      0
# 2          0.3613                  0.08758      0
# 3          0.6638                  0.17300      0
# 4          0.2364                  0.07678      0
#
# [5 rows x 31 columns]

# %%
# number of rows and Columns in this dataset
data_frame.shape
# Out:
# (569, 31)

# %%
# checking for missing values
data_frame.isnull().sum()
# Out:
# mean radius                0
# mean texture               0
# mean perimeter             0
# mean area                  0
# mean smoothness            0
# mean compactness           0
# mean concavity             0
# mean concave points        0
# mean symmetry              0
# mean fractal dimension     0
# radius error               0
# texture error              0
# perimeter error            0
# area error                 0
# smoothness error           0
# compactness error          0
# concavity error            0
# concave points error       0
# symmetry error             0
# fractal dimension error    0
# worst radius               0
# worst texture              0
# worst perimeter            0
# worst area                 0
# worst smoothness           0
# worst compactness          0
# worst concavity            0
# worst concave points       0
# worst symmetry             0
# worst fractal dimension    0
# label                      0
# dtype: int64

# %%
# checking the distribution of Target Varibale
data_frame['label'].value_counts()
# Out:
# 1    357
# 0    212
# Name: label, dtype: int64

# %% [markdown]
# 1 --> Benign
#
# 0 --> Malignant
#
# Separating the features and target

# %%
x = data_frame.drop(columns='label', axis=1)
y = data_frame['label']

# %%
print(x)
# Out:
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0          17.99         10.38          122.80     1001.0          0.11840
# 1          20.57         17.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          11.42         20.38           77.58      386.1          0.14250
# 4          20.29         14.34          135.10     1297.0          0.10030
# ..           ...           ...             ...        ...              ...
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
#      mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0             0.27760         0.30010              0.14710         0.2419
# 1             0.07864         0.08690              0.07017         0.1812
# 2             0.15990         0.19740              0.12790         0.2069
# 3             0.28390         0.24140              0.10520         0.2597
# 4             0.13280         0.19800              0.10430         0.1809
# ..                ...             ...                  ...            ...
# 564           0.11590         0.24390              0.13890         0.1726
# 565           0.10340         0.14400              0.09791         0.1752
# 566           0.10230         0.09251              0.05302         0.1590
# 567           0.27700         0.35140              0.15200         0.2397
# 568           0.04362         0.00000              0.00000         0.1587
#
#      mean fractal dimension  ...  worst radius  worst texture  \
# 0                   0.07871  ...        25.380          17.33
# 1                   0.05667  ...        24.990          23.41
# 2                   0.05999  ...        23.570          25.53
# 3                   0.09744  ...        14.910          26.50
# 4                   0.05883  ...        22.540          16.67
# ..                      ...  ...           ...            ...
# 564                 0.05623  ...        25.450          26.40
# 565                 0.05533  ...        23.690          38.25
# 566                 0.05648  ...        18.980          34.12
# 567                 0.07016  ...        25.740          39.42
# 568                 0.05884  ...         9.456          30.37
#
#      worst perimeter  worst area  worst smoothness  worst compactness  \
# 0             184.60      2019.0           0.16220            0.66560
# 1             158.80      1956.0           0.12380            0.18660
# 2             152.50      1709.0           0.14440            0.42450
# 3              98.87       567.7           0.20980            0.86630
# 4             152.20      1575.0           0.13740            0.20500
# ..               ...         ...               ...                ...
# 564           166.10      2027.0           0.14100            0.21130
# 565           155.00      1731.0           0.11660            0.19220
# 566           126.70      1124.0           0.11390            0.30940
# 567           184.60      1821.0           0.16500            0.86810
# 568            59.16       268.6           0.08996            0.06444
#
#      worst concavity  worst concave points  worst symmetry  \
# 0             0.7119                0.2654          0.4601
# 1             0.2416                0.1860          0.2750
# 2             0.4504                0.2430          0.3613
# 3             0.6869                0.2575          0.6638
# 4             0.4000                0.1625          0.2364
# ..               ...                   ...             ...
# 564           0.4107                0.2216          0.2060
# 565           0.3215                0.1628          0.2572
# 566           0.3403                0.1418          0.2218
# 567           0.9387                0.2650          0.4087
# 568           0.0000                0.0000          0.2871
#
#      worst fractal dimension
# 0                    0.11890
# 1                    0.08902
# 2                    0.08758
# 3                    0.17300
# 4                    0.07678
# ..                       ...
# 564                  0.07115
# 565                  0.06637
# 566                  0.07820
# 567                  0.12400
# 568                  0.07039
#
# [569 rows x 30 columns]

# %%
 X = np.asarray(x)
 Y = np.asarray(y)

# %%
x
# Out:
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0          17.99         10.38          122.80     1001.0          0.11840
# 1          20.57         17.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          11.42         20.38           77.58      386.1          0.14250
# 4          20.29         14.34          135.10     1297.0          0.10030
# ..           ...           ...             ...        ...              ...
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
#      mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0             0.27760         0.30010              0.14710         0.2419
# 1             0.07864         0.08690              0.07017         0.1812
# 2             0.15990         0.19740              0.12790         0.2069
# 3             0.28390         0.24140              0.10520         0.2597
# 4             0.13280         0.19800              0.10430         0.1809
# ..                ...             ...                  ...            ...
# 564           0.11590         0.24390              0.13890         0.1726
# 565           0.10340         0.14400              0.09791         0.1752
# 566           0.10230         0.09251              0.05302         0.1590
# 567           0.27700         0.35140              0.15200         0.2397
# 568           0.04362         0.00000              0.00000         0.1587
#
#      mean fractal dimension  ...  worst radius  worst texture  \
# 0                   0.07871  ...        25.380          17.33
# 1                   0.05667  ...        24.990          23.41
# 2                   0.05999  ...        23.570          25.53
# 3                   0.09744  ...        14.910          26.50
# 4                   0.05883  ...        22.540          16.67
# ..                      ...  ...           ...            ...
# 564                 0.05623  ...        25.450          26.40
# 565                 0.05533  ...        23.690          38.25
# 566                 0.05648  ...        18.980          34.12
# 567                 0.07016  ...        25.740          39.42
# 568                 0.05884  ...         9.456          30.37
#
#      worst perimeter  worst area  worst smoothness  worst compactness  \
# 0             184.60      2019.0           0.16220            0.66560
# 1             158.80      1956.0           0.12380            0.18660
# 2             152.50      1709.0           0.14440            0.42450
# 3              98.87       567.7           0.20980            0.86630
# 4             152.20      1575.0           0.13740            0.20500
# ..               ...         ...               ...                ...
# 564           166.10      2027.0           0.14100            0.21130
# 565           155.00      1731.0           0.11660            0.19220
# 566           126.70      1124.0           0.11390            0.30940
# 567           184.60      1821.0           0.16500            0.86810
# 568            59.16       268.6           0.08996            0.06444
#
#      worst concavity  worst concave points  worst symmetry  \
# 0             0.7119                0.2654          0.4601
# 1             0.2416                0.1860          0.2750
# 2             0.4504                0.2430          0.3613
# 3             0.6869                0.2575          0.6638
# 4             0.4000                0.1625          0.2364
# ..               ...                   ...             ...
# 564           0.4107                0.2216          0.2060
# 565           0.3215                0.1628          0.2572
# 566           0.3403                0.1418          0.2218
# 567           0.9387                0.2650          0.4087
# 568           0.0000                0.0000          0.2871
#
#      worst fractal dimension
# 0                    0.11890
# 1                    0.08902
# 2                    0.08758
# 3                    0.17300
# 4                    0.07678
# ..                       ...
# 564                  0.07115
# 565                  0.06637
# 566                  0.07820
# 567                  0.12400
# 568                  0.07039
#
# [569 rows x 30 columns]

# %% [markdown]
# GridSearchCV
#
#
# GridSearchCV is used for determining the best parameters for our model

# %%
# loading the SVC model
model = SVC()

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.2)

# %%
model.fit(x_train,y_train)
# Out:
# SVC()

# %%
pred=model.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

# %%
print(accuracy_score(pred,y_test))
# Out:
# 0.9122807017543859

# %%
# hyperparameters

parameters = {
              'kernel':['linear','poly','rbf','sigmoid'],
              'C':[1, 5, 10, 20,0.01]
}

# %%
# grid search
classifier = GridSearchCV(model, parameters, cv=5)

# %%
# fitting the data to our model
classifier.fit(X, Y)
# Out:
# GridSearchCV(cv=5, estimator=SVC(),
#              param_grid={'C': [1, 5, 10, 20, 0.01],
#                          'kernel': ['linear', 'poly', 'rbf', 'sigmoid']})

# %%
classifier.cv_results_
# Out:
# {'mean_fit_time': array([3.05730205e+00, 1.03913307e-02, 1.11906528e-02, 2.51560688e-02,
#         6.75171437e+00, 9.99841690e-03, 8.99686813e-03, 2.39827156e-02,
#         1.08555077e+01, 1.40950680e-02, 1.03929043e-02, 2.79837132e-02,
#         1.70589785e+01, 9.19151306e-03, 1.09960079e-02, 2.21860886e-02,
#         4.49745178e-02, 1.11926079e-02, 2.73787022e-02, 2.59847641e-02]),
#  'std_fit_time': array([1.27368270e+00, 4.45085286e-03, 9.80058516e-04, 4.05066382e-03,
#         1.60661980e+00, 6.53401361e-03, 1.99962283e-03, 3.57361311e-03,
#         2.44677347e+00, 6.56449171e-03, 2.33113755e-03, 1.16872174e-02,
#         6.11977642e+00, 3.70589834e-03, 1.41448862e-03, 3.59741641e-03,
#         9.69036413e-03, 3.54517367e-03, 4.49959900e-03, 3.16091793e-03]),
#  'mean_score_time': array([0.00199504, 0.00260124, 0.00859699, 0.00679913, 0.00159888,
#         0.00279675, 0.00379252, 0.00639663, 0.00140104, 0.00220184,
#         0.00339622, 0.00899382, 0.00120072, 0.00120058, 0.00499539,
#         0.00640121, 0.00260081, 0.00499573, 0.01259446, 0.00599566]),
#  'std_score_time': array([0.00154234, 0.00102006, 0.00722558, 0.00098219, 0.00048838,
#         0.0013256 , 0.00074503, 0.00257644, 0.00080116, 0.0007496 ,
#         0.00048934, 0.00303268, 0.00040052, 0.00040047, 0.00167446,
#         0.00224796, 0.00135433, 0.00379356, 0.00534633, 0.00178705]),
#  'param_C': masked_array(data=[1, 1, 1, 1, 5, 5, 5, 5, 10, 10, 10, 10, 20, 20, 20, 20,
#                     0.01, 0.01, 0.01, 0.01],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_kernel': masked_array(data=['linear', 'poly', 'rbf', 'sigmoid', 'linear', 'poly',
#                     'rbf', 'sigmoid', 'linear', 'poly', 'rbf', 'sigmoid',
#                     'linear', 'poly', 'rbf', 'sigmoid', 'linear', 'poly',
#                     'rbf', 'sigmoid'],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'C': 1, 'kernel': 'linear'},
#   {'C': 1, 'kernel': 'poly'},
#   {'C': 1, 'kernel': 'rbf'},
#   {'C': 1, 'kernel': 'sigmoid'},
#   {'C': 5, 'kernel': 'linear'},
#   {'C': 5, 'kernel': 'poly'},
#   {'C': 5, 'kernel': 'rbf'},
#   {'C': 5, 'kernel': 'sigmoid'},
#   {'C': 10, 'kernel': 'linear'},
#   {'C': 10, 'kernel': 'poly'},
#   {'C': 10, 'kernel': 'rbf'},
#   {'C': 10, 'kernel': 'sigmoid'},
#   {'C': 20, 'kernel': 'linear'},
#   {'C': 20, 'kernel': 'poly'},
#   {'C': 20, 'kernel': 'rbf'},
#   {'C': 20, 'kernel': 'sigmoid'},
#   {'C': 0.01, 'kernel': 'linear'},
#   {'C': 0.01, 'kernel': 'poly'},
#   {'C': 0.01, 'kernel': 'rbf'},
#   {'C': 0.01, 'kernel': 'sigmoid'}],
#  'split0_test_score': array([0.94736842, 0.84210526, 0.85087719, 0.54385965, 0.94736842,
#         0.88596491, 0.88596491, 0.49122807, 0.93859649, 0.88596491,
#         0.87719298, 0.48245614, 0.92982456, 0.87719298, 0.87719298,
#         0.47368421, 0.92105263, 0.80701754, 0.75438596, 0.62280702]),
#  'split1_test_score': array([0.92982456, 0.88596491, 0.89473684, 0.45614035, 0.93859649,
#         0.9122807 , 0.92982456, 0.42105263, 0.93859649, 0.92105263,
#         0.92105263, 0.40350877, 0.95614035, 0.92105263, 0.92105263,
#         0.40350877, 0.94736842, 0.83333333, 0.77192982, 0.62280702]),
#  'split2_test_score': array([0.97368421, 0.92982456, 0.92982456, 0.46491228, 0.97368421,
#         0.92105263, 0.93859649, 0.42105263, 0.97368421, 0.90350877,
#         0.9122807 , 0.42105263, 0.95614035, 0.90350877, 0.92105263,
#         0.42105263, 0.99122807, 0.85964912, 0.78070175, 0.63157895]),
#  'split3_test_score': array([0.92105263, 0.94736842, 0.94736842, 0.38596491, 0.92982456,
#         0.93859649, 0.94736842, 0.35087719, 0.94736842, 0.93859649,
#         0.95614035, 0.34210526, 0.93859649, 0.93859649, 0.94736842,
#         0.34210526, 0.92105263, 0.88596491, 0.79824561, 0.63157895]),
#  'split4_test_score': array([0.95575221, 0.9380531 , 0.9380531 , 0.45132743, 0.96460177,
#         0.95575221, 0.95575221, 0.37168142, 0.96460177, 0.95575221,
#         0.94690265, 0.36283186, 0.96460177, 0.95575221, 0.9380531 ,
#         0.3539823 , 0.95575221, 0.88495575, 0.84070796, 0.62831858]),
#  'mean_test_score': array([0.94553641, 0.90866325, 0.91217202, 0.46044093, 0.95081509,
#         0.92272939, 0.93150132, 0.41117839, 0.95256948, 0.920975  ,
#         0.92271386, 0.40239093, 0.9490607 , 0.91922062, 0.92094395,
#         0.39886664, 0.94729079, 0.85418413, 0.78919422, 0.6274181 ]),
#  'std_test_score': array([0.01868869, 0.03938232, 0.03544367, 0.05025317, 0.01621632,
#         0.02368918, 0.02435811, 0.04857818, 0.01419963, 0.02470123,
#         0.02787898, 0.0489065 , 0.01281637, 0.02730027, 0.02410455,
#         0.0476401 , 0.02599603, 0.0304835 , 0.02938499, 0.00394868]),
#  'rank_test_score': array([ 5, 13, 12, 17,  2,  7,  6, 18,  1,  9,  8, 19,  3, 11, 10, 20,  4,
#         14, 15, 16])}

# %%
# best parameters

best_parameters = classifier.best_params_
print(best_parameters)
# Out:
# {'C': 10, 'kernel': 'linear'}

# %%
# higest accuracy

highest_accuracy = classifier.best_score_
print(highest_accuracy)
# Out:
# 0.9525694767893185

# %%
# loading the results to pandas dataframe
result = pd.DataFrame(classifier.cv_results_)

# %%
result.head()
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time param_C  \
# 0       2.043267      0.849658         0.001200        0.000401       1
# 1       0.006197      0.000979         0.001199        0.000400       1
# 2       0.007794      0.000748         0.003798        0.000400       1
# 3       0.017989      0.002096         0.004198        0.000399       1
# 4       4.525810      0.940340         0.001200        0.000401       5
#
#   param_kernel                         params  split0_test_score  \
# 0       linear   {'C': 1, 'kernel': 'linear'}           0.947368
# 1         poly     {'C': 1, 'kernel': 'poly'}           0.842105
# 2          rbf      {'C': 1, 'kernel': 'rbf'}           0.850877
# 3      sigmoid  {'C': 1, 'kernel': 'sigmoid'}           0.543860
# 4       linear   {'C': 5, 'kernel': 'linear'}           0.947368
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 0           0.929825           0.973684           0.921053           0.955752
# 1           0.885965           0.929825           0.947368           0.938053
# 2           0.894737           0.929825           0.947368           0.938053
# 3           0.456140           0.464912           0.385965           0.451327
# 4           0.938596           0.973684           0.929825           0.964602
#
#    mean_test_score  std_test_score  rank_test_score
# 0         0.945536        0.018689                4
# 1         0.908663        0.039382               12
# 2         0.912172        0.035444               11
# 3         0.460441        0.050253               13
# 4         0.950815        0.016216                2

# %%
grid_search_result = result[['param_C','param_kernel','mean_test_score']]

# %%
grid_search_result
# Out:
#    param_C param_kernel  mean_test_score
# 0        1       linear         0.945536
# 1        1         poly         0.908663
# 2        1          rbf         0.912172
# 3        1      sigmoid         0.460441
# 4        5       linear         0.950815
# 5        5         poly         0.922729
# 6        5          rbf         0.931501
# 7        5      sigmoid         0.411178
# 8       10       linear         0.952569
# 9       10         poly         0.920975
# 10      10          rbf         0.922714
# 11      10      sigmoid         0.402391
# 12      20       linear         0.949061
# 13      20         poly         0.919221
# 14      20          rbf         0.920944
# 15      20      sigmoid         0.398867

# %% [markdown]
# Highest Accuracy = 95.2%
#
# Best Parameters = {'C':10, 'kernel':'linear'}

# %% [markdown]
# # RandomizedSearchCV

# %%
# loading the SVC model
model = SVC()

# %%
# hyperparameters

parameters = {
              'kernel':['linear','poly','rbf','sigmoid'],
              'C':[1, 5, 10, 20]
}

# %%
# grid search
classifier = RandomizedSearchCV(model, parameters, cv=5)

# %%
# fitting the data to our model
classifier.fit(X, Y)
# Out:
# RandomizedSearchCV(cv=5, estimator=SVC(),
#                    param_distributions={'C': [1, 5, 10, 20],
#                                         'kernel': ['linear', 'poly', 'rbf',
#                                                    'sigmoid']})

# %%
classifier.cv_results_
# Out:
# {'mean_fit_time': array([2.98637118, 6.2639967 , 0.00939622, 0.02518415, 0.01099319,
#         0.02338529, 0.00959315, 0.0091928 , 8.74046569, 0.02318621]),
#  'std_fit_time': array([1.14436368e+00, 1.43985247e+00, 1.62671638e-03, 4.82999516e-03,
#         1.99859271e-03, 4.91727775e-03, 2.15593451e-03, 2.92141889e-03,
#         2.05945783e+00, 4.25811174e-03]),
#  'mean_score_time': array([0.00179925, 0.00140004, 0.00239677, 0.00479755, 0.00479589,
#         0.00699701, 0.00419559, 0.00522189, 0.00099964, 0.00479698]),
#  'std_score_time': array([9.80425838e-04, 4.91304126e-04, 7.97774707e-04, 7.47844386e-04,
#         1.71898793e-03, 1.26192411e-03, 1.16439943e-03, 1.58253734e-03,
#         8.17605410e-07, 1.16593475e-03]),
#  'param_kernel': masked_array(data=['linear', 'linear', 'poly', 'sigmoid', 'rbf',
#                     'sigmoid', 'rbf', 'rbf', 'linear', 'sigmoid'],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False],
#         fill_value='?',
#              dtype=object),
#  'param_C': masked_array(data=[1, 5, 20, 5, 5, 1, 10, 20, 10, 10],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'kernel': 'linear', 'C': 1},
#   {'kernel': 'linear', 'C': 5},
#   {'kernel': 'poly', 'C': 20},
#   {'kernel': 'sigmoid', 'C': 5},
#   {'kernel': 'rbf', 'C': 5},
#   {'kernel': 'sigmoid', 'C': 1},
#   {'kernel': 'rbf', 'C': 10},
#   {'kernel': 'rbf', 'C': 20},
#   {'kernel': 'linear', 'C': 10},
#   {'kernel': 'sigmoid', 'C': 10}],
#  'split0_test_score': array([0.94736842, 0.94736842, 0.87719298, 0.49122807, 0.88596491,
#         0.54385965, 0.87719298, 0.87719298, 0.93859649, 0.48245614]),
#  'split1_test_score': array([0.92982456, 0.93859649, 0.92105263, 0.42105263, 0.92982456,
#         0.45614035, 0.92105263, 0.92105263, 0.93859649, 0.40350877]),
#  'split2_test_score': array([0.97368421, 0.97368421, 0.90350877, 0.42105263, 0.93859649,
#         0.46491228, 0.9122807 , 0.92105263, 0.97368421, 0.42105263]),
#  'split3_test_score': array([0.92105263, 0.92982456, 0.93859649, 0.35087719, 0.94736842,
#         0.38596491, 0.95614035, 0.94736842, 0.94736842, 0.34210526]),
#  'split4_test_score': array([0.95575221, 0.96460177, 0.95575221, 0.37168142, 0.95575221,
#         0.45132743, 0.94690265, 0.9380531 , 0.96460177, 0.36283186]),
#  'mean_test_score': array([0.94553641, 0.95081509, 0.91922062, 0.41117839, 0.93150132,
#         0.46044093, 0.92271386, 0.92094395, 0.95256948, 0.40239093]),
#  'std_test_score': array([0.01868869, 0.01621632, 0.02730027, 0.04857818, 0.02435811,
#         0.05025317, 0.02787898, 0.02410455, 0.01419963, 0.0489065 ]),
#  'rank_test_score': array([ 3,  2,  7,  9,  4,  8,  5,  6,  1, 10])}

# %%
# best parameters

best_parameters = classifier.best_params_
print(best_parameters)
# Out:
# {'kernel': 'linear', 'C': 10}

# %%
# higest accuracy

highest_accuracy = classifier.best_score_
print(highest_accuracy)
# Out:
# 0.9525694767893185

# %%
# loading the results to pandas dataframe
result = pd.DataFrame(classifier.cv_results_)

# %%
result.head()
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time param_kernel  \
# 0       2.986371      1.144364         0.001799        0.000980       linear
# 1       6.263997      1.439852         0.001400        0.000491       linear
# 2       0.009396      0.001627         0.002397        0.000798         poly
# 3       0.025184      0.004830         0.004798        0.000748      sigmoid
# 4       0.010993      0.001999         0.004796        0.001719          rbf
#
#   param_C                         params  split0_test_score  \
# 0       1   {'kernel': 'linear', 'C': 1}           0.947368
# 1       5   {'kernel': 'linear', 'C': 5}           0.947368
# 2      20    {'kernel': 'poly', 'C': 20}           0.877193
# 3       5  {'kernel': 'sigmoid', 'C': 5}           0.491228
# 4       5      {'kernel': 'rbf', 'C': 5}           0.885965
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 0           0.929825           0.973684           0.921053           0.955752
# 1           0.938596           0.973684           0.929825           0.964602
# 2           0.921053           0.903509           0.938596           0.955752
# 3           0.421053           0.421053           0.350877           0.371681
# 4           0.929825           0.938596           0.947368           0.955752
#
#    mean_test_score  std_test_score  rank_test_score
# 0         0.945536        0.018689                3
# 1         0.950815        0.016216                2
# 2         0.919221        0.027300                7
# 3         0.411178        0.048578                9
# 4         0.931501        0.024358                4

# %%
randomized_search_result = result[['param_C','param_kernel','mean_test_score']]

# %%
randomized_search_result
# Out:
#   param_C param_kernel  mean_test_score
# 0       1          rbf         0.912172
# 1       1      sigmoid         0.460441
# 2       5         poly         0.922729
# 3       5          rbf         0.931501
# 4       5       linear         0.950815
# 5      10       linear         0.952569
# 6      20       linear         0.949061
# 7      10      sigmoid         0.402391
# 8       1       linear         0.945536
# 9      20         poly         0.919221

# %% [markdown]
# Highest Accuracy = 95.2%
#
# Best Parameters = {'C':10, 'kernel':'linear'}
